# %%
s = {123, 51, 52, 663}
s1 = {45, 52, 51, 775}

# %%
from IPython.display import Image
Image("Screenshot 2023-09-21 235204.png")

# %%
s.add(22)

# %%
s
# Out:
# {22, 51, 52, 123, 663}

# %%
s2 = s.copy()

# %%
s2
# Out:
# {22, 51, 52, 123, 663}

# %%
s.clear()

# %%
s
# Out:
# set()

# %%
s1.difference(s2)
# Out:
# {45, 775}

# %%
s2.difference(s1)
# Out:
# {22, 123, 663}

# %%
s1.difference_update(s2)

# %%
s1
# Out:
# {45, 775}

# %%
s2.discard(123)

# %%
s2
# Out:
# {22, 51, 52, 663}

# %%
s2.remove(663)

# %%
s2
# Out:
# {22, 51, 52}

# %%
s1.add(51)

# %%
s2.pop()
# Out:
# 51

# %%
s2.add(51)

# %%
s1.intersection(s2)
# Out:
# {51}

# %%
s1.union(s2)
# Out:
# {22, 45, 51, 52, 775}

# %%
s1.intersection_update(s2)

# %%
s1
# Out:
# {51}

# %%
s1.union_update(s2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 s1.union_update(s2)
#
# AttributeError: 'set' object has no attribute 'union_update'

# %%
s1.update([32, 12, 55])

# %%
s1
# Out:
# {12, 32, 51, 55}

# %%
s1.isdisjoint(s2)
# Out:
# False

# %%
s2
# Out:
# {22, 51, 52}

# %%
s2.isdisjoint(s1)
# Out:
# False

# %%
s3.clear()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 s3.clear()
#
# NameError: name 's3' is not defined

# %%
s3 = {51,}

# %%
s3
# Out:
# {51}

# %%
s3.isdisjoint(s2)
# Out:
# False

# %%
s2.isdisjoint(s3)
# Out:
# False

# %%
print(s1)
print(s2)
# Out:
# {32, 51, 12, 55}
# {51, 52, 22}

# %%
s2.issubset(s1)
# Out:
# False

# %%
s3.clear()

# %%
s3.update([32, 51, 12])

# %%
s3.issubset(s1)
# Out:
# True

# %%
s1.issuperset(s2)
# Out:
# False

# %%
s1.symmetric_difference(s2)
# Out:
# {12, 22, 32, 52, 55}

# %%
s1.symmetric_difference_update(s2)

# %%
s1
# Out:
# {12, 22, 32, 52, 55}
